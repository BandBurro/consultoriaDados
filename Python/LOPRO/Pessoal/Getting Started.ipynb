# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# testano o bgl legal

# %%
"This asdnalskds"
# Out:
# 'This asdnalskds'

# %%
conta = 2+2
conta * 3
# Out:
# 12

# %%
from google.colab import userdata
userdata.get('tetano')
# Out:
# '12381209830123'

# %%
print("test")
# Out:
# test

# %% [markdown]
# # New Section

# %% [markdown]
# testano o bgl legal dms *vei* *italicized text*

# %% [markdown]
# # Create a Variable

# %% [markdown]
# variable_name = value

# %%
salary = 100000

# %%
print(salary)
# Out:
# 100000

# %%
base_salary = int(input("Qual o seu salario?"))
bonus_rate = int(input("Qual a sua pretenção salarial?"))
total_salary = base_salary / bonus_rate
print("O seu pedido de aumento é proprocional a " + str(total_salary) + "%")
# Out:
# Qual o seu salario?10
# Qual a sua pretenção salarial?19
# O seu pedido de aumento é proprocional a 0.5263157894736842%

# %% [markdown]
# # Calculate the Following

# %%
Total_Salary = (base_salary)*(1+(bonus_rate))
base_salary = 1000
bonus_rate = 0.2
print(Total_Salary)
# Out:
# 1200.0

# %%
# prompt: create me 3 variables, one with a boolean value true, one with an 12000 int and the last one with job title, which can be data scientist

is_wfh = True
salary = 12000
job_title = "Data Scientist"
company_name = 'Mc. Donalds'
job_id = 101
print('data job description')
print('++++++++++++++++++++')
print('Working Method:', is_wfh)
print('Salary:', salary)
print('Titulo:', job_title)
print('Nome da Empresa:', company_name)
print('ID:', job_id)
# Out:
# data job description
# ++++++++++++++++++++
# Working Method: True
# Salary: 12000
# Titulo: Data Scientist
# Nome da Empresa: Mc. Donalds
# ID: 101

# %% [markdown]
# # Objects
